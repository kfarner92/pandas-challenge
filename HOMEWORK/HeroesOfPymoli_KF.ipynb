# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# Raw data file
file_to_load = "Instructions/HeroesOfPymoli/Resources/purchase_data.csv"

# Read purchasing file and store into pandas data frame
purchase_data_df = pd.read_csv(file_to_load)
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
player_count = len(purchase_data_df['SN'].unique())
'Number of Players is ' + str(player_count)
# Out:
# 'Number of Players is 576'

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
item_count = len(purchase_data_df['Item ID'].unique())
average_price = purchase_data_df['Price'].mean()
total_sales = len(purchase_data_df['Item ID'])
#max_price = purchase_data_df['Price'].max()
#min_price = purchase_data_df['Price'].min()
#most_popular_item = purchase_data_df['Item Name'].mode()
#most_popular_item_rev = purchase_data_df.loc[purchase_data_df['Item Name'] == 'Final Critic', 'Price']
#most_popular_item_rev = most_popular_item_rev.sum()
total_revenue = purchase_data_df['Price'].sum()

# %%
purchase_total_df = pd.DataFrame({
    '# of Players':[player_count],
    '# of Items':[item_count],
    'Avg Price':[average_price],
    '# of Sales' :[total_sales],
    'Total Revenue' : [total_revenue]
#    'Most Expensive Item':[max_price],
#    'Least Expensive Item':[min_price],
#    'Most Popular Item':[most_popular_item],
#    'Most Pupular Item Profit':[most_popular_item_rev]
                                 })
purchase_total_df['Avg Price']=purchase_total_df['Avg Price'].map('${:.2f}'.format)
purchase_total_df['Total Revenue']=purchase_total_df['Total Revenue'].map('${:.2f}'.format)
purchase_total_df
# Out:
#    # of Players  # of Items Avg Price  # of Sales Total Revenue
# 0           576         183     $3.05         780      $2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
gender_df = purchase_data_df[['Gender','SN']]
gender_group = gender_df.groupby(['Gender'])
gender_group['SN'].unique().count()
percentage_g = gender_group.count()
total_g = percentage_g['SN'].sum()
percentage_g['Percentage']= percentage_g['SN']/total_g
percentage_g['Percentage']=percentage_g['Percentage'].map('{:.2%}'.format)
percentage_g
# Out:
#                         SN Percentage
# Gender
# Female                 113     14.49%
# Male                   652     83.59%
# Other / Non-Disclosed   15      1.92%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, etc. by gender
#
#
# * For normalized purchasing, divide total purchase value by purchase count, by gender
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
purchase_data_df.set_index(['Purchase ID'])

#Gender seperated dataframes parsed and calculated
male_df = purchase_data_df.loc[purchase_data_df['Gender']== 'Male']
male_items = len(male_df['Purchase ID'])
male_average = male_df['Price'].mean()
male_total = male_df['Price'].sum()
male_normalized = male_total/male_items

female_df = purchase_data_df.loc[purchase_data_df['Gender']== 'Female']
female_items = len(female_df['Purchase ID'])
female_average = female_df['Price'].mean()
female_total = female_df['Price'].sum()
female_normalized = female_total/female_items

other_df = purchase_data_df.loc[purchase_data_df['Gender']== 'Other / Non-Disclosed']
other_items = len(other_df['Purchase ID'])
other_average = other_df['Price'].mean()
other_total = other_df['Price'].sum()
other_normalized = other_total/other_items

# %%
#combine seperate gender dataframes
gen_purch_df = pd.DataFrame({
        'Gender':['Male','Female','Other / Non-Disclosed'],
        'Purchase Count':[male_items,female_items,other_items],
        'Average Purchase Price':[male_average,female_average,other_average],
        'Total Purchase Value':[male_total, female_total, other_total],
        'Normalized Totals':[male_normalized, female_normalized, other_normalized]          
                        })
gen_purch_df['Average Purchase Price']=gen_purch_df['Average Purchase Price'].map('${:.2f}'.format)
gen_purch_df['Normalized Totals']=gen_purch_df['Normalized Totals'].map('${:.2f}'.format)
gen_purch_df['Total Purchase Value']=gen_purch_df['Total Purchase Value'].map('${:,.2f}'.format)
gen_purch_df
# Out:
#                   Gender  Purchase Count Average Purchase Price  \
# 0                   Male             652                  $3.02
# 1                 Female             113                  $3.20
# 2  Other / Non-Disclosed              15                  $3.35
#
#   Total Purchase Value Normalized Totals
# 0            $1,967.64             $3.02
# 1              $361.94             $3.20
# 2               $50.19             $3.35

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Establish bins for ages
age_df = purchase_data_df
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
age_df['Age Group']= pd.cut(purchase_data_df['Age'],age_bins,labels=group_names)
age_df = age_df.groupby(['Age Group'])
group_percent = (age_df['Age Group'].count() / total_g).rename('Age Percent')
group = (age_df['Age Group'].count()).rename('Count')
combine_df = pd.concat([group,group_percent],axis=1)
combine_df['Age Percent']=combine_df['Age Percent'].map('{:.2%}'.format)
combine_df
# Out:
#            Count Age Percent
# Age Group
# <10           23       2.95%
# 10-14         28       3.59%
# 15-19        136      17.44%
# 20-24        365      46.79%
# 25-29        101      12.95%
# 30-34         73       9.36%
# 35-39         41       5.26%
# 40+           13       1.67%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, etc. in the table below
#
#
# * Calculate Normalized Purchasing
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
age_count = (age_df['Age Group'].count()).rename('Purchase Count')
age_average = (age_df['Price'].mean()).rename('Average Purchase Price')
age_sum = (age_df['Price'].sum()).rename('Total Purchase Value')
age_normalized = (age_sum / group).rename('Normalized Totals')
combine_df = pd.concat([age_count,age_average,age_sum,age_normalized],axis=1)

combine_df['Average Purchase Price']=combine_df['Average Purchase Price'].map('${:.2f}'.format)
combine_df['Normalized Totals']=combine_df['Normalized Totals'].map('${:.2f}'.format)
combine_df['Total Purchase Value']=combine_df['Total Purchase Value'].map('${:,.2f}'.format)
combine_df
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Group
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#           Normalized Totals
# Age Group
# <10                   $3.35
# 10-14                 $2.96
# 15-19                 $3.04
# 20-24                 $3.05
# 25-29                 $2.90
# 30-34                 $2.93
# 35-39                 $3.60
# 40+                   $2.94

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
top_df = purchase_data_df
top_df = top_df.groupby(['SN'])
player_purch = (top_df['Price'].sum()).rename('Total Purchase Value')
player_items = (top_df['Item ID'].count()).rename('Purchase Count')
player_avg = (player_purch/player_items).rename('Average Purchases Price')

player_combine_df = pd.concat([player_items,player_avg,player_purch],axis=1)
player_combine_df.nlargest(5,'Total Purchase Value')

player_final_df = player_combine_df.nlargest(5,'Total Purchase Value')

player_final_df['Average Purchases Price']=player_final_df['Average Purchases Price'].map('${:.2f}'.format)
player_final_df['Total Purchase Value']=player_final_df['Total Purchase Value'].map('${:,.2f}'.format)

player_final_df
# Out:
#              Purchase Count Average Purchases Price Total Purchase Value
# SN
# Lisosia93                 5                   $3.79               $18.96
# Idastidru52               4                   $3.86               $15.45
# Chamjask73                3                   $4.61               $13.83
# Iral74                    4                   $3.40               $13.62
# Iskadarya95               3                   $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
items_df = purchase_data_df[['Purchase ID','Item ID','Item Name','Price']]
items_df= items_df.groupby('Item ID')
item_sum = (items_df['Price'].sum()).rename("Total Purchase Value")
item_sales = (items_df['Item ID'].count()).rename('Purchase Count')
item_combine_df = pd.concat([item_sales,item_sum],axis=1)
add_df = purchase_data_df[['Item ID','Item Name','Price']]
add_df = add_df.drop_duplicates()
add_df= add_df.set_index('Item ID')
item_merge = pd.merge(item_combine_df,add_df, on ='Item ID')
item_final =item_merge.nlargest(5,'Purchase Count')
item_final = item_final.sort_values(['Item ID'],ascending=False)

item_final['Total Purchase Value']=item_final['Total Purchase Value'].map('${:,.2f}'.format)
item_final['Price']=item_final['Price'].map('${:,.2f}'.format)

item_final
# Out:
#          Purchase Count Total Purchase Value  \
# Item ID
# 178                  12               $50.76
# 145                   9               $41.22
# 108                   9               $31.77
# 82                    9               $44.10
# 19                    8                $8.16
#
#                                             Item Name  Price
# Item ID
# 178      Oathbreaker, Last Hope of the Breaking Storm  $4.23
# 145                              Fiery Glass Crusader  $4.58
# 108         Extraction, Quickblade Of Trembling Hands  $3.53
# 82                                            Nirvana  $4.90
# 19                      Pursuit, Cudgel of Necromancy  $1.02

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
item_final =item_merge.nlargest(5,'Total Purchase Value')
item_final = item_final.sort_values(['Total Purchase Value'],ascending=False)

item_final['Total Purchase Value']=item_final['Total Purchase Value'].map('${:,.2f}'.format)
item_final['Price']=item_final['Price'].map('${:,.2f}'.format)

item_final
# Out:
#          Purchase Count Total Purchase Value  \
# Item ID
# 178                  12               $50.76
# 82                    9               $44.10
# 145                   9               $41.22
# 92                    8               $39.04
# 103                   8               $34.80
#
#                                             Item Name  Price
# Item ID
# 178      Oathbreaker, Last Hope of the Breaking Storm  $4.23
# 82                                            Nirvana  $4.90
# 145                              Fiery Glass Crusader  $4.58
# 92                                       Final Critic  $4.88
# 103                                    Singed Scalpel  $4.35
